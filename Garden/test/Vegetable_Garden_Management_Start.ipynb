# %%
# 農作業管理プログラムのスタート画面起動　20251115確認

# 起動するとブラウザに選択ボタンが表示される（start_page.pyで制御）
# 関連するファイル（データベース）は以下の通り
# vegetable_garden_photo_ex2.xlsx　作業記録のメインのデータベース
# 作業カレンダー.xlsx
# 野菜育成コメント.xlsx
# 連作障害.xlsx Crop_Performance
# 連作障害.xlsx Schedule
# 記録写真はJPGファイルで、GoogleDrive G:\その他のパソコン\マイ ノートパソコン\Pictures\Vegetables に保存されている

# !streamlit run C:\Users\kawgu\OneDrive\ドキュメント\USB Backup\PythonWork\農作業\start_page.py
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Streamlit requires raw Python (.py) files, but the provided file has no extension.
# For more information, please see https://docs.streamlit.io

# %%
# !streamlit run C:\Users\kawgu\OneDrive\ドキュメント\USB Backup\PythonWork\農作業\sakutuke_gantt.py
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Streamlit requires raw Python (.py) files, but the provided file has no extension.
# For more information, please see https://docs.streamlit.io

# %%
# !streamlit run C:\Users\kawgu\OneDrive\ドキュメント\USB Backup\PythonWork\農作業\layout_view.py
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Streamlit requires raw Python (.py) files, but the provided file has no extension.
# For more information, please see https://docs.streamlit.io

# %%
import 空き畝検索
import openpyxl
# Out:
# 全体期間: 2026-01-01 ～ 2027-02-28
#
# ★ 2か月以上連続して空いている畝のリスト
#   畝       空き開始       空き終了  空き日数  空き月数(概算)
# A01 2026-03-01 2026-04-30    61       2.0
# A02 2026-03-01 2026-04-30    61       2.0
# A03 2026-03-01 2026-04-30    61       2.0
# A04 2026-03-01 2026-04-30    61       2.0
# A05 2026-03-01 2026-04-30    61       2.0
# A06 2026-03-01 2026-04-30    61       2.0
# A08 2026-03-01 2026-08-31   184       6.1
# A11 2026-07-23 2026-11-30   131       4.4
# A14 2026-03-01 2026-09-19   203       6.8
# A14 2026-03-01 2026-11-30   275       9.2
# A15 2026-03-01 2026-07-31   153       5.1
# B01 2026-03-01 2026-05-09    70       2.3
# B02 2026-03-01 2026-07-31   153       5.1
# B05 2026-03-01 2026-04-30    61       2.0
# B07 2026-06-03 2026-11-30   181       6.0
# B08 2026-07-03 2026-11-30   151       5.0
# B09 2026-09-03 2026-11-30    89       3.0
# B10 2026-07-23 2026-11-30   131       4.4
# B11 2026-06-17 2026-11-30   167       5.6
# B12 2026-09-12 2026-11-30    80       2.7
# ...
